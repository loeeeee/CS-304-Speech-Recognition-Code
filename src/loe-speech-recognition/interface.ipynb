# %%
# from segmentation import Segmentation
from visualization_librosa import Visualization as VisualizationRosa
from visualization import Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
# # Good Mic Setup
# Segmentation.speech_high_threshold = 128
# Segmentation.speech_low_threshold = 16
# Segmentation.silence_duration_threshold = 0.2
# seg = Segmentation.from_basic(
#     sample_rate=16000,
#     save_path="../../segment_results"
# )
# # Words
# seg.main()

# %%
visR = VisualizationRosa(audio_path="../../segment_results/result.wav")
visR.main()

# %%
vis = Visualization(audio_path="../../segment_results/result.wav")
vis.plot_spectrogram()

# %%
vis.plot_log_spectrogram()
# Out:
# (161, 264)
# (161,)
# (264,)

# %%
vis.plot_spectrogram_2()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 vis.plot_spectrogram_2()
#
# File ~/Projects/CS-304-Speech-Recognition-Code/src/loe-speech-recognition/visualization.py:111, in Visualization.plot_spectrogram_2(self)
#     110 def plot_spectrogram_2(self):
# --> 111     result, freq, timestamp = self._fft()
#     112     # print(10*np.log10(result))
#     113     print(freq.shape)
#
# File ~/Projects/CS-304-Speech-Recognition-Code/src/loe-speech-recognition/visualization.py:67, in Visualization._fft(self)
#      65 for index, frames in enumerate(zip(audio_frames[:-3], audio_frames[1:-2], audio_frames[2:])):
#      66     frame = np.concatenate(frames)
# ---> 67     windowed_frame = frame * self.fft_window
#      68     frequency_domain_windowed_frame = np.log(np.abs(sp.fft.fft(windowed_frame)) + 1e-10)
# ...
